# %%
import pandas as pd

# Read in track metadata with genre labels
tracks = pd.read_csv("fma-rock-vs-hiphop.csv")

# Read in track metrics with the features
echonest_metrics = pd.read_json("echonest-metrics.json",precise_float = True)

# Merge the relevant columns of tracks and echonest_metrics
echo_tracks = pd.merge(echonest_metrics, tracks[['track_id', 'genre_top']],  on = 'track_id', )

# Inspect the resultant dataframe
echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
# track_id            4802 non-null int64
# acousticness        4802 non-null float64
# danceability        4802 non-null float64
# energy              4802 non-null float64
# instrumentalness    4802 non-null float64
# liveness            4802 non-null float64
# speechiness         4802 non-null float64
# tempo               4802 non-null float64
# valence             4802 non-null float64
# genre_top           4802 non-null object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %%
echo_tracks.head()
# Out:
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2       341      0.977282      0.468808  0.134975          0.687700  0.105381
# 3     46204      0.953349      0.498525  0.552503          0.924391  0.684914
# 4     46205      0.613229      0.500320  0.487992          0.936811  0.637750
#
#    speechiness    tempo   valence genre_top
# 0     0.159310  165.922  0.576661   Hip-Hop
# 1     0.461818  126.957  0.269240   Hip-Hop
# 2     0.073124  119.646  0.430707      Rock
# 3     0.028885   78.958  0.430448      Rock
# 4     0.030327  112.667  0.824749      Rock

# %%
tracks.head()
# Out:
#    track_id  bit_rate  comments        composer         date_created  \
# 0       135    256000         1             NaN  2008-11-26 01:43:26
# 1       136    256000         1             NaN  2008-11-26 01:43:35
# 2       151    192000         0             NaN  2008-11-26 01:44:55
# 3       152    192000         0             NaN  2008-11-26 01:44:58
# 4       153    256000         0  Arc and Sender  2008-11-26 01:45:00
#
#          date_recorded  duration  favorites genre_top    genres  ...  \
# 0  2008-11-26 00:00:00       837          0      Rock  [45, 58]  ...
# 1  2008-11-26 00:00:00       509          0      Rock  [45, 58]  ...
# 2                  NaN       192          0      Rock      [25]  ...
# 3                  NaN       193          0      Rock      [25]  ...
# 4  2008-11-26 00:00:00       405          5      Rock      [26]  ...
#
#   information interest  language_code  \
# 0         NaN     2484             en
# 1         NaN     1948             en
# 2         NaN      701             en
# 3         NaN      637             en
# 4         NaN      354             en
#
#                                              license listens  lyricist number  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1832       NaN      0
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1498       NaN      0
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...     148       NaN      4
# 3  Attribution-NonCommercial-ShareAlike 3.0 Inter...      98       NaN     11
# 4  Attribution-NonCommercial-NoDerivatives (aka M...     424       NaN      2
#
#    publisher tags                       title
# 0        NaN   []                Father's Day
# 1        NaN   []  Peel Back The Mountain Sky
# 2        NaN   []                 Untitled 04
# 3        NaN   []                 Untitled 11
# 4        NaN   []          Hundred-Year Flood
#
# [5 rows x 21 columns]

# %%
echonest_metrics.head()
# Out:
#       track_id  acousticness  danceability    energy  instrumentalness  \
# 0            2      0.416675      0.675894  0.634476          0.010628
# 1            3      0.374408      0.528643  0.817461          0.001851
# 10         145      0.235506      0.438672  0.487752          0.716122
# 100        341      0.977282      0.468808  0.134975          0.687700
# 1000      3457      0.081256      0.897197  0.367886          0.104474
#
#       liveness  speechiness    tempo   valence
# 0     0.177647     0.159310  165.922  0.576661
# 1     0.105880     0.461818  126.957  0.269240
# 10    0.070359     0.047298  120.790  0.650452
# 100   0.105381     0.073124  119.646  0.430707
# 1000  0.085845     0.041271  100.744  0.749293

# %%
# Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row0_col2 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row0_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row0_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row0_col5 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row0_col6 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row0_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row0_col8 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row1_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row1_col4 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row1_col5 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row1_col6 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row1_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row1_col8 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row2_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row2_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row2_col3 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row2_col4 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row2_col6 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row2_col8 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row3_col0 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row3_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row3_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row3_col4 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row3_col5 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row3_col6 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row3_col7 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row3_col8 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row4_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row4_col1 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row4_col3 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row4_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row4_col7 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row5_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row5_col1 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row5_col2 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row5_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row5_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row5_col6 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row5_col7 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row5_col8 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row6_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row6_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row6_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row6_col3 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44de2f28_31a7_11ea_b42c_dc719609c7e2row6_col5 {
#             background-color:  #eae6f1;
#             color:  #000000;

# %%
# Define our features 
features = echo_tracks.drop(['genre_top','track_id'], axis = 1)

# Define our labels
labels = echo_tracks['genre_top']

# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)

# %%
scaled_train_features
# Out:
# array([[-0.19121034,  1.30442004,  0.03831594, ...,  0.37303429,
#          1.15397908,  0.46228696],
#        [-0.30603598,  0.50188641,  0.78817624, ...,  2.44615517,
#          0.00791367, -0.69081137],
#        [ 1.33175726,  0.17577737, -2.00860733, ..., -0.21760802,
#         -0.2071225 , -0.08516731],
#        ...,
#        [-1.19562265,  1.21982456, -0.02755233, ..., -0.50802959,
#          0.30398179,  0.16360869],
#        [-0.81143025,  0.35467614,  1.12914186, ..., -0.43474536,
#         -0.0478822 ,  1.43072604],
#        [-0.91924354,  1.01380468, -0.52706203, ..., -0.45309447,
#         -0.19588685, -0.73217359]])

# %%
# This is just to make plots appear in the notebook
# %matplotlib inline

# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get our explained variance ratios from PCA using all features
pca = PCA()
scaled_training_pca = pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(len(exp_variance)),exp_variance)
ax.set_xlabel('Principal Component #')
# Out:
# Text(0.5, 0, 'Principal Component #')

# %%
# Import numpy
import numpy as np

# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(scaled_training_pca)

# %%
print(cum_exp_variance)
# Out:
# [PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)]
